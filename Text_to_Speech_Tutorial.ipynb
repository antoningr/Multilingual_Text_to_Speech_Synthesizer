# %% [markdown]
# # 🗣️ Multilingual Text-to-Speech (TTS) Tutorial
#
# In this notebook, we explore how to convert text into natural-sounding speech using the [Google Text-to-Speech (gTTS)](https://pypi.org/project/gTTS/) library in Python.
#
# We will:
# - Use `gTTS` to synthesize speech
# - Explore language options
# - Detect language automatically
# - Visualize audio outputs
#
# Let's get started!

# %%
# Requirements
# !pip install gTTS pydub langdetect IPython matplotlib seaborn

# %%
# Imports
from gtts import gTTS
from langdetect import detect
from pydub import AudioSegment
from IPython.display import Audio, display
import io, re
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
# Show Supported Languages by gTTS
from gtts.lang import tts_langs
import pandas as pd

# Get the languages supported by gTTS
langs = tts_langs()

# Create a DataFrame with flags
langs_df = pd.DataFrame([
    {
        "Language": f"{name}",
        "Code": code
    }
    for code, name in langs.items()
])

# Sort and display
langs_df = langs_df.sort_values("Language").reset_index(drop=True)
langs_df.style.set_properties(**{"text-align": "left"})
# Out:
# <style type="text/css">
# #T_6d062_row0_col0, #T_6d062_row0_col1, #T_6d062_row1_col0, #T_6d062_row1_col1, #T_6d062_row2_col0, #T_6d062_row2_col1, #T_6d062_row3_col0, #T_6d062_row3_col1, #T_6d062_row4_col0, #T_6d062_row4_col1, #T_6d062_row5_col0, #T_6d062_row5_col1, #T_6d062_row6_col0, #T_6d062_row6_col1, #T_6d062_row7_col0, #T_6d062_row7_col1, #T_6d062_row8_col0, #T_6d062_row8_col1, #T_6d062_row9_col0, #T_6d062_row9_col1, #T_6d062_row10_col0, #T_6d062_row10_col1, #T_6d062_row11_col0, #T_6d062_row11_col1, #T_6d062_row12_col0, #T_6d062_row12_col1, #T_6d062_row13_col0, #T_6d062_row13_col1, #T_6d062_row14_col0, #T_6d062_row14_col1, #T_6d062_row15_col0, #T_6d062_row15_col1, #T_6d062_row16_col0, #T_6d062_row16_col1, #T_6d062_row17_col0, #T_6d062_row17_col1, #T_6d062_row18_col0, #T_6d062_row18_col1, #T_6d062_row19_col0, #T_6d062_row19_col1, #T_6d062_row20_col0, #T_6d062_row20_col1, #T_6d062_row21_col0, #T_6d062_row21_col1, #T_6d062_row22_col0, #T_6d062_row22_col1, #T_6d062_row23_col0, #T_6d062_row23_col1, #T_6d062_row24_col0, #T_6d062_row24_col1, #T_6d062_row25_col0, #T_6d062_row25_col1, #T_6d062_row26_col0, #T_6d062_row26_col1, #T_6d062_row27_col0, #T_6d062_row27_col1, #T_6d062_row28_col0, #T_6d062_row28_col1, #T_6d062_row29_col0, #T_6d062_row29_col1, #T_6d062_row30_col0, #T_6d062_row30_col1, #T_6d062_row31_col0, #T_6d062_row31_col1, #T_6d062_row32_col0, #T_6d062_row32_col1, #T_6d062_row33_col0, #T_6d062_row33_col1, #T_6d062_row34_col0, #T_6d062_row34_col1, #T_6d062_row35_col0, #T_6d062_row35_col1, #T_6d062_row36_col0, #T_6d062_row36_col1, #T_6d062_row37_col0, #T_6d062_row37_col1, #T_6d062_row38_col0, #T_6d062_row38_col1, #T_6d062_row39_col0, #T_6d062_row39_col1, #T_6d062_row40_col0, #T_6d062_row40_col1, #T_6d062_row41_col0, #T_6d062_row41_col1, #T_6d062_row42_col0, #T_6d062_row42_col1, #T_6d062_row43_col0, #T_6d062_row43_col1, #T_6d062_row44_col0, #T_6d062_row44_col1, #T_6d062_row45_col0, #T_6d062_row45_col1, #T_6d062_row46_col0, #T_6d062_row46_col1, #T_6d062_row47_col0, #T_6d062_row47_col1, #T_6d062_row48_col0, #T_6d062_row48_col1, #T_6d062_row49_col0, #T_6d062_row49_col1, #T_6d062_row50_col0, #T_6d062_row50_col1, #T_6d062_row51_col0, #T_6d062_row51_col1, #T_6d062_row52_col0, #T_6d062_row52_col1, #T_6d062_row53_col0, #T_6d062_row53_col1, #T_6d062_row54_col0, #T_6d062_row54_col1, #T_6d062_row55_col0, #T_6d062_row55_col1, #T_6d062_row56_col0, #T_6d062_row56_col1, #T_6d062_row57_col0, #T_6d062_row57_col1, #T_6d062_row58_col0, #T_6d062_row58_col1, #T_6d062_row59_col0, #T_6d062_row59_col1, #T_6d062_row60_col0, #T_6d062_row60_col1, #T_6d062_row61_col0, #T_6d062_row61_col1, #T_6d062_row62_col0, #T_6d062_row62_col1, #T_6d062_row63_col0, #T_6d062_row63_col1, #T_6d062_row64_col0, #T_6d062_row64_col1, #T_6d062_row65_col0, #T_6d062_row65_col1, #T_6d062_row66_col0, #T_6d062_row66_col1, #T_6d062_row67_col0, #T_6d062_row67_col1, #T_6d062_row68_col0, #T_6d062_row68_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_6d062">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d062_level0_col0" class="col_heading level0 col0" >Language</th>
#       <th id="T_6d062_level0_col1" class="col_heading level0 col1" >Code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d062_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6d062_row0_col0" class="data row0 col0" >Afrikaans</td>
#       <td id="T_6d062_row0_col1" class="data row0 col1" >af</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6d062_row1_col0" class="data row1 col0" >Albanian</td>
#       <td id="T_6d062_row1_col1" class="data row1 col1" >sq</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6d062_row2_col0" class="data row2 col0" >Amharic</td>
#       <td id="T_6d062_row2_col1" class="data row2 col1" >am</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6d062_row3_col0" class="data row3 col0" >Arabic</td>
#       <td id="T_6d062_row3_col1" class="data row3 col1" >ar</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6d062_row4_col0" class="data row4 col0" >Basque</td>
#       <td id="T_6d062_row4_col1" class="data row4 col1" >eu</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6d062_row5_col0" class="data row5 col0" >Bengali</td>
#       <td id="T_6d062_row5_col1" class="data row5 col1" >bn</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6d062_row6_col0" class="data row6 col0" >Bosnian</td>
#       <td id="T_6d062_row6_col1" class="data row6 col1" >bs</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6d062_row7_col0" class="data row7 col0" >Bulgarian</td>
#       <td id="T_6d062_row7_col1" class="data row7 col1" >bg</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6d062_row8_col0" class="data row8 col0" >Cantonese</td>
#       <td id="T_6d062_row8_col1" class="data row8 col1" >yue</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6d062_row9_col0" class="data row9 col0" >Catalan</td>
#       <td id="T_6d062_row9_col1" class="data row9 col1" >ca</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6d062_row10_col0" class="data row10 col0" >Chinese (Mandarin)</td>
#       <td id="T_6d062_row10_col1" class="data row10 col1" >zh</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6d062_row11_col0" class="data row11 col0" >Chinese (Mandarin/Taiwan)</td>
#       <td id="T_6d062_row11_col1" class="data row11 col1" >zh-TW</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6d062_row12_col0" class="data row12 col0" >Chinese (Simplified)</td>
#       <td id="T_6d062_row12_col1" class="data row12 col1" >zh-CN</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6d062_row13_col0" class="data row13 col0" >Croatian</td>
#       <td id="T_6d062_row13_col1" class="data row13 col1" >hr</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6d062_row14_col0" class="data row14 col0" >Czech</td>
#       <td id="T_6d062_row14_col1" class="data row14 col1" >cs</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6d062_row15_col0" class="data row15 col0" >Danish</td>
#       <td id="T_6d062_row15_col1" class="data row15 col1" >da</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6d062_row16_col0" class="data row16 col0" >Dutch</td>
#       <td id="T_6d062_row16_col1" class="data row16 col1" >nl</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6d062_row17_col0" class="data row17 col0" >English</td>
#       <td id="T_6d062_row17_col1" class="data row17 col1" >en</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6d062_row18_col0" class="data row18 col0" >Estonian</td>
#       <td id="T_6d062_row18_col1" class="data row18 col1" >et</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_6d062_row19_col0" class="data row19 col0" >Filipino</td>
#       <td id="T_6d062_row19_col1" class="data row19 col1" >tl</td>
#     </tr>
#     <tr>
#       <th id="T_6d062_level0_row20" class="row_heading level0 row20" >20</th>

# %% [markdown]
# ###  **English Language**

# %%
# Sample text
sample_text = """
    Hello! 
    This is a multilingual text-to-speech demo. 
    You can type or paste any text here, and it will be converted into spoken audio. 
    Try changing the language or speech speed to see how it sounds in different voices. 
    Have fun exploring the power of speech synthesis!
"""

# %%
# Show text stats
char_count = len(sample_text)
word_count = len(sample_text.split())
print(f"Characters: {char_count} | Words: {word_count}")
# Out:
# Characters: 291 | Words: 46

# %%
# Detect language
lang_code = detect(sample_text)
print(f"Detected language code: {lang_code}")
# Out:
# Detected language code: en

# %%
# Generate speech from text
tts = gTTS(text=sample_text, lang=lang_code, slow=False)

# Save to memory buffer
mp3_fp = io.BytesIO()
tts.write_to_fp(mp3_fp)
mp3_fp.seek(0)

# Playback audio in notebook
Audio(mp3_fp.read(), autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ###  **Try Another Language**

# %%
# Sample text for an another languages (e.g. French)
sample_text = """
    Bonjour !
    Ceci est une démonstration de synthèse vocale multilingue.
    Vous pouvez saisir ou coller n'importe quel texte ici, et il sera converti en audio.
    Essayez de changer la langue ou le débit de parole pour voir comment le son est reproduit avec différentes voix.
    Amusez-vous à explorer la puissance de la synthèse vocale !
"""

# %%
# Show text stats
char_count = len(sample_text)
word_count = len(sample_text.split())
print(f"Characters: {char_count} | Words: {word_count}")
# Out:
# Characters: 348 | Words: 55

# %%
# Detect language
lang_code = detect(sample_text)
print(f"Detected language code: {lang_code}")
# Out:
# Detected language code: fr

# %%
# Generate speech from text
tts = gTTS(text=sample_text, lang=lang_code, slow=False)

# Save to memory buffer
mp3_fp = io.BytesIO()
tts.write_to_fp(mp3_fp)
mp3_fp.seek(0)

# Playback audio in notebook
Audio(mp3_fp.read(), autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
